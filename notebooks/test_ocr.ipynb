# %%
import confnotebook
import paddle

paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# /mnt/data/projects/rusal_recon_srv/repo/recon_vision/.venv/lib/python3.11/site-packages/paddle/pir/math_op_patch.py:241: UserWarning: Tensor do not have 'place' interface for pir graph mode, try not to use it. None will be returned.
#   warnings.warn(

# %%
from pathlib import Path

import cv2
from paddleocr import PaddleOCR
from PIL import Image, ImageDraw, ImageFont

from vision_core.detector.table_detector import TableDetector
from vision_core.entities.bbox import BBox
from vision_core.entities.paragraph import Paragraph, ParagraphType
from vision_core.entities.table import Table
from vision_core.loader.pdf_loader import PDFLoader
from vision_core.preprocessor.image_preprocessor import ImagePreprocessor

PADDING = 5
source = Path("../examples/1C")
output = Path("../examples/output/ocr_test")

files = sorted(source.glob("*.pdf"))
print(f"Found {len(files)} PDF files in {source}")
file = files[3]
print(f"Processing file: {file.name}")

pdf_bytes = file.read_bytes()

loader = PDFLoader(pdf_bytes=pdf_bytes)

ocr = PaddleOCR(
    text_recognition_model_name="cyrillic_PP-OCRv5_mobile_rec",
    text_recognition_model_dir="../models/cyrillic_PP-OCRv5_mobile_rec",
    text_detection_model_name="PP-OCRv5_server_det",
    text_detection_model_dir="../models/PP-OCRv5_server_det",
    use_doc_orientation_classify=True, 
    use_doc_unwarping=False, 
    use_textline_orientation=False, 
    device='gpu',
    )



img = loader.get_page_image(page_num=0, dpi=200)
detector_tbl = TableDetector()
preprocessor = ImagePreprocessor()

cleaned = preprocessor.process(img)

cleaned_ocr = cv2.cvtColor(cleaned, cv2.COLOR_BGR2RGB)

# Image.fromarray(cleaned_ocr).show()

tables: list[Table] = detector_tbl.detect_tables(cleaned)

full_res = ocr.predict(cleaned_ocr)[0]
print(full_res.json)
full_boxes = full_res["rec_boxes"]
full_texts = full_res["rec_texts"]
full_scores = full_res["rec_scores"]

for table in tables:
    for cell in table.cells:
        if cell.value is None:
            cell.value = ""
        for bb, text, score in zip(full_boxes, full_texts, full_scores, strict=False):
            # optional quality filter
            if score < 0.7:
                continue
            abs_bb = BBox(
                x_min=bb[0],
                y_min=bb[1],
                x_max=bb[2],
                y_max=bb[3],
            )
            if cell.bbox.contains_center(abs_bb):
                cell.value += text + "\n"
                cell.blobs.append(abs_bb)

# detect paragraphs on image without tables
paragraphs: list[Paragraph] = []
for bb, text, score in zip(full_boxes, full_texts, full_scores, strict=False):
    if score < 0.7:
        continue
    abs_bb = BBox(x_min=bb[0], y_min=bb[1], x_max=bb[2], y_max=bb[3])
    inside_table = any(tbl.bbox.padding(PADDING).contains_center(abs_bb) for tbl in tables)
    if not inside_table:
        paragraphs.append(
            Paragraph(
                id="",
                text=text,
                bbox=abs_bb,
                type=ParagraphType.TEXT,
            )
        )

# отрисовка результатов
src = Image.fromarray(img)
overlay = src.convert("RGBA")
dst = Image.new("RGB", src.size, (255, 255, 255))

src_draw = ImageDraw.Draw(overlay, "RGBA")
dst_draw = ImageDraw.Draw(dst)
fnt = ImageFont.truetype("DejaVuSans.ttf", 20)


for para in paragraphs:
    x1, y1, x2, y2 = para.bbox.to_tuple()
    dst_draw.text((x1 + 2, y1 + 2), text=para.text, fill="black", font=fnt)
    src_draw.rectangle(((x1, y1), (x2, y2)), fill=(144, 238, 144, 128)) # set lightblue

for table in tables:
    for cell in table.cells:
        x1, y1, x2, y2 = cell.bbox.to_tuple()
        dst_draw.rectangle(((x1, y1), (x2, y2)), outline="black", width=2)
        dst_draw.text((x1 + 2, y1 + 2), text=cell.value, fill="black", font=fnt)

        for word_bbox in cell.blobs:
            wb_x1, wb_y1, wb_x2, wb_y2 = word_bbox.to_tuple()
            src_draw.rectangle(((wb_x1, wb_y1), (wb_x2, wb_y2)), fill=(144, 238, 144, 128))

src_result = Image.alpha_composite(src.convert("RGBA"), overlay).convert("RGB")
combinesd_image = Image.new("RGB", (src.width * 2, src.height))
combinesd_image.paste(src_result, (0, 0))
combinesd_image.paste(dst, (src.width, 0))
combinesd_image.save(f"{file.stem}_ocr_result.png")
# Out:
# Creating model: ('PP-OCRv5_server_det', '../models/PP-OCRv5_server_det')
# Found 12 PDF files in ../examples/1C
# Processing file: АС ВНИИМ Менделеева Д.И. - РУ на 31.12.24.pdf
# Creating model: ('cyrillic_PP-OCRv5_mobile_rec', '../models/cyrillic_PP-OCRv5_mobile_rec')
# 2026-03-30 15:16:00.232 | DEBUG    | vision_core.preprocessor.table_preprocessor:create_table_mask:27 - Min lengths - Horizontal: 70, Vertical: 10
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': False, 'use_textline_orientation': False}, 'dt_polys': [[[209, 87], [276, 96], [272, 121], [206, 112]], [[282, 97], [318, 115], [306, 139], [270, 121]], [[366, 101], [395, 101], [395, 177], [366, 177]], [[433, 101], [463, 101], [457, 567], [427, 567]], [[463, 101], [493, 101], [490, 617], [459, 617]], [[524, 103], [552, 104], [547, 301], [519, 300]], [[553, 104], [583, 104], [580, 324], [550, 323]], [[645, 103], [673, 103], [673, 194], [645, 194]], [[675, 105], [704, 105], [704, 194], [675, 194]], [[828, 105], [856, 105], [856, 197], [828, 197]], [[860, 105], [885, 105], [885, 196], [860, 196]], [[1010, 104], [1038, 105], [1036, 197], [1008, 197]], [[1039, 105], [1068, 105], [1068, 197], [1039, 197]], [[1128, 105], [1156, 105], [1154, 317], [1126, 317]], [[1187, 102], [1218, 102], [1216, 674], [1185, 674]], [[1234, 103], [1268, 103], [1265, 489], [1231, 488]], [[1266, 101], [1306, 101], [1293, 2144], [1253, 2144]], [[1298, 101], [1338, 101], [1325, 2144], [1285, 2144]], [[136, 112], [189, 90], [198, 112], [145, 133]], [[1157, 129], [1187, 129], [1187, 189], [1157, 189]], [[223, 147], [236, 144], [239, 159], [226, 162]], [[736, 142], [764, 142], [763, 468], [735, 468]], [[918, 141], [948, 141], [946, 456], [916, 455]], [[1098, 139], [1128, 139], [1126, 456], [1096, 455]], [[176, 150], [217, 143], [220, 163], [179, 169]], [[175, 219], [193, 311], [176, 315], [158