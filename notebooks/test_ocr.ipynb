# %%
import confnotebook
import paddle

paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# /mnt/data/projects/rusal_recon_srv/repo/recon_vision/.venv/lib/python3.11/site-packages/paddle/pir/math_op_patch.py:241: UserWarning: Tensor do not have 'place' interface for pir graph mode, try not to use it. None will be returned.
#   warnings.warn(

# %%
from pathlib import Path

import cv2
from paddleocr import PaddleOCR
from PIL import Image, ImageDraw, ImageFont

from vision_core.detector.table_detector import TableDetector
from vision_core.entities.bbox import BBox
from vision_core.entities.paragraph import Paragraph, ParagraphType
from vision_core.entities.table import Table
from vision_core.loader.pdf_loader import PDFLoader
from vision_core.preprocessor.image_preprocessor import ImagePreprocessor

PADDING = 5
source = Path("../examples/1C")
output = Path("../examples/output/ocr_test")

files = sorted(source.glob("*.pdf"))
print(f"Found {len(files)} PDF files in {source}")
file = files[0]
print(f"Processing file: {file.name}")

pdf_bytes = file.read_bytes()

loader = PDFLoader(pdf_bytes=pdf_bytes)

ocr = PaddleOCR(
    text_recognition_model_name="cyrillic_PP-OCRv5_mobile_rec",
    text_recognition_model_dir="../models/cyrillic_PP-OCRv5_mobile_rec",
    text_detection_model_name="PP-OCRv5_server_det",
    text_detection_model_dir="../models/PP-OCRv5_server_det",
    use_doc_orientation_classify=True, 
    use_doc_unwarping=False, 
    use_textline_orientation=False, 
    device='gpu',
    )



img = loader.get_page_image(page_num=0, dpi=200)
detector_tbl = TableDetector()
preprocessor = ImagePreprocessor()

cleaned = preprocessor.process(img)

cleaned_ocr = cv2.cvtColor(cleaned, cv2.COLOR_BGR2RGB)

# Image.fromarray(cleaned_ocr).show()

tables: list[Table] = detector_tbl.detect_tables(cleaned)

full_res = ocr.predict(cleaned_ocr)[0]
print(full_res.json)
full_boxes = full_res["rec_boxes"]
full_texts = full_res["rec_texts"]
full_scores = full_res["rec_scores"]

for table in tables:
    for cell in table.cells:
        if cell.value is None:
            cell.value = ""
        for bb, text, score in zip(full_boxes, full_texts, full_scores, strict=False):
            # optional quality filter
            if score < 0.7:
                continue
            abs_bb = BBox(
                x_min=bb[0],
                y_min=bb[1],
                x_max=bb[2],
                y_max=bb[3],
            )
            if cell.bbox.contains_center(abs_bb):
                cell.value += text + "\n"
                cell.blobs.append(abs_bb)

# detect paragraphs on image without tables
paragraphs: list[Paragraph] = []
for bb, text, score in zip(full_boxes, full_texts, full_scores, strict=False):
    if score < 0.7:
        continue
    abs_bb = BBox(x_min=bb[0], y_min=bb[1], x_max=bb[2], y_max=bb[3])
    inside_table = any(tbl.bbox.padding(PADDING).contains_center(abs_bb) for tbl in tables)
    if not inside_table:
        paragraphs.append(
            Paragraph(
                id="",
                text=text,
                bbox=abs_bb,
                type=ParagraphType.TEXT,
            )
        )

# отрисовка результатов
src = Image.fromarray(img)
overlay = src.convert("RGBA")
dst = Image.new("RGB", src.size, (255, 255, 255))

src_draw = ImageDraw.Draw(overlay, "RGBA")
dst_draw = ImageDraw.Draw(dst)
fnt = ImageFont.truetype("DejaVuSans.ttf", 20)


for para in paragraphs:
    x1, y1, x2, y2 = para.bbox.to_tuple()
    dst_draw.text((x1 + 2, y1 + 2), text=para.text, fill="black", font=fnt)
    src_draw.rectangle(((x1, y1), (x2, y2)), fill=(144, 238, 144, 128)) # set lightblue

for table in tables:
    for cell in table.cells:
        x1, y1, x2, y2 = cell.bbox.to_tuple()
        dst_draw.rectangle(((x1, y1), (x2, y2)), outline="black", width=2)
        dst_draw.text((x1 + 2, y1 + 2), text=cell.value, fill="black", font=fnt)

        for word_bbox in cell.blobs:
            wb_x1, wb_y1, wb_x2, wb_y2 = word_bbox.to_tuple()
            src_draw.rectangle(((wb_x1, wb_y1), (wb_x2, wb_y2)), fill=(144, 238, 144, 128))

src_result = Image.alpha_composite(src.convert("RGBA"), overlay).convert("RGB")
combinesd_image = Image.new("RGB", (src.width * 2, src.height))
combinesd_image.paste(src_result, (0, 0))
combinesd_image.paste(dst, (src.width, 0))
combinesd_image.save(f"{file.stem}_ocr_result.png")
# Out:
# Creating model: ('PP-LCNet_x1_0_doc_ori', None)
# Model files already exist. Using cached files. To redownload, please delete the directory manually: `/home/dev/.paddlex/official_models/PP-LCNet_x1_0_doc_ori`.
# Creating model: ('PP-OCRv5_server_det', '../models/PP-OCRv5_server_det')
# Found 12 PDF files in ../examples/1C
# Processing file: АС ВНИИМ Менделеева Д.И. - БРАЗ на 31.12.24 (сверен).pdf
# Creating model: ('cyrillic_PP-OCRv5_mobile_rec', '../models/cyrillic_PP-OCRv5_mobile_rec')
# 2026-03-30 15:18:46.115 | DEBUG    | vision_core.preprocessor.table_preprocessor:create_table_mask:27 - Min lengths - Horizontal: 70, Vertical: 9
# 2026-03-30 15:18:46.155 | DEBUG    | vision_core.detector.table_detector:detect_tables:59 - Найдена таблица table_0: c 27 строк и 8 столбцов
# {'res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_preprocessor': True, 'use_textline_orientation': False}, 'doc_preprocessor_res': {'input_path': None, 'page_index': None, 'model_settings': {'use_doc_orientation_classify': True, 'use_doc_unwarping': False}, 'angle': 0}, 'dt_polys': [[[699, 119], [923, 119], [923, 150], [699, 150]], [[635, 156], [985, 156], [985, 179], [635, 179]], [[437, 179], [1183, 179], [1183, 203], [437, 203]], [[606, 200], [1013, 202], [1013, 226], [606, 224]], [[80, 261], [1540, 268], [1540, 291], [79, 284]], [[263, 285], [482, 287], [482, 308], [262, 306]], [[738, 288], [1540, 290], [1540, 313], [738, 311]], [[81, 310], [444, 312], [444, 332], [80, 330]], [[78, 344], [617, 347], [617, 368], [77, 364]], [[811, 347], [1106, 348], [1106, 369], [811, 368]], [[97, 366], [143, 366], [143, 389], [97, 389]], [[279, 366], [360, 366], [360, 391], [279, 391]], [[534, 369], [585, 369], [585, 391], [534, 391]], [[697, 368], [758, 368], [758, 394], [697, 394]], [[830, 369], [874, 369], [874, 393], [830, 393]], [[1010, 369], [1089, 369], [1089, 394], [1010, 394]], [[1263, 369], [1315, 369], [1315, 393], [1263, 393]], [[1426, 367], [1487, 370], [1486, 396], [1425, 393]], [[79, 387], [235, 391], [234, 412], [78, 408]], [[565, 391], [643, 391], [643, 412], [565, 412]], [[811, 390], [966, 394], [966, 415], [811, 411]], [[1230, 395], [1310, 395], [1310, 416], [1230, 416]], [[1372, 387], [1541, 391], [1540, 415], [1372, 411]], [[122, 408], [344, 410], [344, 431], [122, 430]], [[330, 434], [475, 434], [475, 454], [330, 454]], [[731, 433], [811, 433], [811, 457], [731, 457]], [[1060, 436], [1205, 436], [1205, 456], [1060, 456]], [[1293, 434], [1374, 434], [1374, 458], [1293, 458]], [[79, 453], [151, 453], [151, 474], [79, 474]], [[142, 453], [391, 454], [391, 475], [142, 474]], [[565, 457], [642, 457], [642, 475], [565, 475]], [[310, 475], [474, 479], [474, 500], [310, 497]], [[564, 477], [642, 477], [642, 498], [564, 498]], [[1041, 478], [1206, 480], [1206, 501], [1041, 499]], [[339, 497], [475, 499], [475, 520], [339, 518]], [[1070, 499], [1206, 501], [1205, 522], [1069, 520]], [[121, 517], [325, 518], [325, 539], [121, 538]], [[329, 540], [475, 543], [475, 564], [329, 561]], [[565, 542], [643, 542], [643, 563], [565, 563]], [[1060, 544], [1206, 544], [1206, 564], [1060, 564]], [[1461, 543], [1540, 543], [1540, 564], [1461, 564]], [[78, 559], [148, 562], [148, 583], [77, 581]], [[158, 561], [369, 563], [369, 583], [158, 581]], [[733, 566], [809, 566], [809, 584], [733, 584]], [[309, 584], [474, 587], [474, 608], [309, 605]], [[731, 585], [810, 587], [810, 608], [730, 606]], [[1041, 586], [1206, 589], [1205, 610], [1041, 607]], [[339, 606], [475, 608], [475, 629], [339, 627]], [[1069, 608], [1207, 610], [1206, 631], [1068, 629]], [[122, 628], [344, 628], [344, 648], [122, 648]], [[328, 650], [475, 652], [475, 672], [328, 670]], [[1059, 651], [1206, 653], [1206, 674], [1058, 672]], [[77, 669], [145, 669], [145, 690], [77, 690]], [[161, 670], [350, 671], [350, 692], [161, 691]], [[732, 673], [810, 673], [810, 694], [732, 694]], [[78, 692], [146, 692], [146, 713], [78, 713]], [[162, 693], [380, 694], [380, 715], [162, 714]], [[564, 695], [643, 695], [643, 716], [564, 716]], [[309, 716], [474, 719], [474, 739], [309, 736]], [[564, 717], [642, 717], [642, 738], [564, 738]], [[732, 717], [810, 717], [810, 738], [732, 738]], [[1040, 717], [1205, 720], [1204, 741], [1040, 738]], [[338, 737], [474, 739], [474, 760], [338, 758]], [[1069, 740], [1204, 740], [1204, 760], [1069, 760]], [[121, 759], [344, 759], [344, 779], [121, 779]], [[328, 781], [475, 783], [475, 803], [328, 801]], [[1058, 782], [1206, 784], [1206, 805], [1058, 803]], [[76, 799], [146, 801], [146, 823], [75, 821]], [[161, 802], [359, 803], [359, 824], [161, 823]], [[733, 806], [809, 806], [809, 824], [733, 824]], [[76, 824], [146, 824], [146, 845], [76, 845]], [[162, 826], [380, 826], [380, 846], [162, 846]], [[564, 826], [642, 826], [642, 84 ...

# %%
from paddleocr import DocImgOrientationClassification

model = DocImgOrientationClassification(model_name="PP-LCNet_x1_0_doc_ori", model_dir="../models/PP-LCNet_x1_0_doc_ori")

output = model.predict(img)

for res in output:
    print(res.json)
# Out:
# {'res': {'input_path': None, 'page_index': None, 'class_ids': [0], 'scores': [0.9198700189590454], 'label_names': ['0']}}
